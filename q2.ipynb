# %%
import numpy as np
x=np.array([1,2,3,4,5])
print(x)
print(type(x))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
l1=[1,2,3,4,5]
print(x)
print(type(l1))
# Out:
# [1 2 3 4 5]
# <class 'list'>

# %%
import numpy as np
x=np.array([1,2,"Ankit","JAva",4.7j])
print(x)
print(type(x[0]))
# Out:
# ['1' '2' 'Ankit' 'JAva' '4.7j']
# <class 'numpy.str_'>

# %%
import numpy as np
l=[]
for i in range(1,7):
    l1=input("ENter the number: ")
    l.append(l1)
print(np.array(l))
