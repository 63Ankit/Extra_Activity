# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/sales_data.csv",encoding='ISO-8859-1')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.count()
# Out:
# User_ID             11251
# Cust_name           11251
# Product_ID          11251
# Gender              11251
# Age Group           11251
# Age                 11251
# Marital_Status      11251
# State               11251
# Zone                11251
# Occupation          11251
# Product_Category    11251
# Orders              11251
# Amount              11239
# Status                  0
# unnamed1                0
# dtype: int64

# %%
df['Status']=df['Status'].fillna("Sucess")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
var={"Age Group":"Age_Group",}
df.rename(columns=var,inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age_Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df['Age_Group']
# Out:
# 0        26-35
# 1        26-35
# 2        26-35
# 3         0-17
# 4        26-35
#          ...
# 11246    18-25
# 11247    26-35
# 11248    36-45
# 11249    36-45
# 11250    18-25
# Name: Age_Group, Length: 11251, dtype: object

# %%
df

# %%
# how to rename the name of data present in the column

# %%
var={"F":"Female",'M':"Male"}
df['Gender']=df['Gender'].map(var)
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  Female     26-35   28               0
# 1      1000732       Kartik  P00110942  Female     26-35   35               1
# 2      1001990        Bindu  P00118542  Female     26-35   35               1
# 3      1001425       Sudevi  P00237842    Male      0-17   16               0
# 4      1000588         Joni  P00057942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning  P00296942    Male     18-25   19               1
# 11247  1004089  Reichenbach  P00171342    Male     26-35   33               0
# 11248  1001209        Oshin  P00201342  Female     36-45   40               0
# 11249  1004023       Noonan  P00059442    Male     36-45   37               0
# 11250  1002744      Brumley  P00281742  Female     18-25   19               0
#
# ...

# %%
var=round(df['Age'].mean())
var
# Out:
# 35

# %%
df['Product_ID']=df['Product_ID'].str.strip('P00')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Group  Age  Marital_Status  \
# 0      1002903    Sanskriti     125942  Female     26-35   28               0
# 1      1000732       Kartik     110942  Female     26-35   35               1
# 2      1001990        Bindu     118542  Female     26-35   35               1
# 3      1001425       Sudevi     237842    Male      0-17   16               0
# 4      1000588         Joni      57942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning     296942    Male     18-25   19               1
# 11247  1004089  Reichenbach     171342    Male     26-35   33               0
# 11248  1001209        Oshin     201342  Female     36-45   40               0
# 11249  1004023       Noonan      59442    Male     36-45   37               0
# 11250  1002744      Brumley     281742  Female     18-25   19               0
#
# ...

# %%
df['Cust_name']=df['Cust_name'].str.upper()

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Group  Age  Marital_Status  \
# 0      1002903    SANSKRITI     125942  Female     26-35   28               0
# 1      1000732       KARTIK     110942  Female     26-35   35               1
# 2      1001990        BINDU     118542  Female     26-35   35               1
# 3      1001425       SUDEVI     237842    Male      0-17   16               0
# 4      1000588         JONI      57942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      MANNING     296942    Male     18-25   19               1
# 11247  1004089  REICHENBACH     171342    Male     26-35   33               0
# 11248  1001209        OSHIN     201342  Female     36-45   40               0
# 11249  1004023       NOONAN      59442    Male     36-45   37               0
# 11250  1002744      BRUMLEY     281742  Female     18-25   19               0
#
# ...

# %%
# How to drop the column.
# How to drop the Row.

# %%
df=df.drop(['unnamed1'],axis=1)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Group  Age  Marital_Status  \
# 0      1002903    SANSKRITI     125942  Female     26-35   28               0
# 1      1000732       KARTIK     110942  Female     26-35   35               1
# 2      1001990        BINDU     118542  Female     26-35   35               1
# 3      1001425       SUDEVI     237842    Male      0-17   16               0
# 4      1000588         JONI      57942    Male     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      MANNING     296942    Male     18-25   19               1
# 11247  1004089  REICHENBACH     171342    Male     26-35   33               0
# 11248  1001209        OSHIN     201342  Female     36-45   40               0
# 11249  1004023       NOONAN      59442    Male     36-45   37               0
# 11250  1002744      BRUMLEY     281742  Female     18-25   19               0
#
# ...

# %%
df.iloc[0,7][0:4]
# Out:
# 'Maha'
