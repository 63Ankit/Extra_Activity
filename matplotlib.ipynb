# %%
from matplotlib import pyplot as plt

# %%
x=[10,20,30,40]
y=[20,40,60,80]
c=["r","y","g","b"]
plt.bar(x,y,color=c)
plt.show()

# %%
import matplotlib.pyplot as plt
x=["python", "C","C++","Java"]
y=[94,74,58,90]
c=["r","y","g","b"]
plt.xlabel("Language",fontsize=15)
plt.ylabel("Famous",fontsize=15)
plt.title("Programmming Language Data",fontsize=15)
plt.bar(x,y,width=0.4,color=c,edgecolor="r",label="Ankit")
plt.show()

# %%
import numpy as np
products = ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Keyboard']
width=0.2
sales_2024 = [120, 200, 150, 90, 60]
sales_2025 = [140, 220, 130, 100, 80]
p=np.arange(len(products))
p1=[j+width for j in p]
plt.bar(p,sales_2024,width, color="g", edgecolor="r",label="2024")
plt.bar(p1,sales_2025,width, color="b", edgecolor="y",label="2025")
plt.xticks(p+width,products)
plt.legend()

plt.show()

# %%
import numpy as np
products = ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Keyboard']
width=0.2
sales_2024 = [120, 200, 150, 90, 60]
sales_2025 = [140, 220, 130, 100, 80]
p=np.arange(len(products))
p1=[j+width for j in p]
plt.barh(products,sales_2024,width, color="g", edgecolor="r",label="2024")
plt.barh(p1,sales_2025,width, color="b", edgecolor="y",label="2025")
plt.xticks(p+width,products)
plt.legend()

plt.show()

# %%
x=[10,20,30,40]
y=[20,40,60,80]
c=["r","y","g","b"]
plt.barh(y,x,color=c)
plt.show()

# %% [raw]
# # draw a line in a diagram from position (0,0) to position (6,250)

# %%
x=[0,6]
y=[0,250]
c=['r','b']
plt.plot(x,y, color='c')
plt.show()

# %%
# ploting points which are not in straight line.
x=[2,5,9,12,15,19]
y=[20,10,40,15,60,70]
plt.plot(x,y)
plt.show()

# %% [raw]
# # plotting without line

# %%
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y, 'o')
plt.show()

# %%
x=np.array([3,6,1,13,5])
plt.plot(x,marker='o')
plt.show()

# %% [raw]
# # multiple lines in one plot

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100] 
#years = [1990,1992,1994,1996,1998,2000,2003,2005,2007,2010] 
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
plt.plot(years, kohli, label="Virat Kohli") 
plt.plot(years, sehwag, label="Virender Sehwag") 
plt.xlabel("Year") 
plt.ylabel("Runs Scored") 
plt.title("Performance Comparison") 
plt.legend() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 #years = [1990,1992,1994,1996,1998,2000,2003,2005,2007,2010]
#       3 sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
# ----> 4 plt.plot(years, kohli, label="Virat Kohli")
#       5 plt.plot(years, sehwag, label="Virender Sehwag")
#       6 plt.xlabel("Year")
#
# NameError: name 'years' is not defined

# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(18,28)
y=np.random.randint(10,20,size=(10))

plt.plot(x,y)
plt.xlabel('Age')
plt.ylabel('number of death')
plt.title('Data Details')
plt.show()

# %%
student25 = [35, 33, 45, 41, 50, 55, 49, 74, 85, 91] 
#years = [1990,1992,1994,1996,1998,2000,2003,2005,2007,2010]
student24 = [45, 54, 76, 35, 78, 56, 77, 89, 69, 96]
plt.plot(years,student24,label='2024')
plt.plot(years,student25,label='2025')
plt.legend()
plt.show()

# %%
import numpy as np 
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500] 
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0] 
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100] 
Year=np.arange(2001,2011)
x = np.arange(len(Year))  # index positions 
width = 0.25
plt.bar(x - width, sachin, width, label="Sachin") 
plt.bar(x, sehwag, width, label="Sehwag") 
plt.bar(x + width, kohli, width, label="Kohli") 
plt.xlabel("Year") 
plt.ylabel("Runs") 
plt.title("Run Comparison") 
plt.xticks(x, Year)  # Show actual year instead of 0,1,2,... 
plt.legend() 
plt.tight_layout() 
plt.show()

# %%
import numpy as np 
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500] 
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0] 
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
Year=np.arange(2000,2010)
x = np.arange(len(Year))  # Index positions 
width = 0.25
plt.barh(x - width, sachin, width, label="Sachin") 
plt.barh(x, sehwag, width, label="Sehwag") 
plt.barh(x + width, kohli, width, label="Kohli") 
plt.xlabel("Runs") 
plt.ylabel("Year") 
plt.title("Run Comparison") 
plt.yticks(x, Year)  # Show actual year instead of 0,1,2,... 
plt.legend() 
plt.tight_layout() 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Runs data
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

# Define years
years = np.arange(2001, 2011)  # Example: 2001–2010

y = np.arange(len(years))  # index positions
height = 0.25              # thickness of each bar

# Horizontal bars
plt.barh(y - height, sachin, height=height, label="Sachin")
plt.barh(y, sehwag, height=height, label="Sehwag")
plt.barh(y + height, kohli, height=height, label="Kohli")

# Labels and title
plt.ylabel("Year")
plt.xlabel("Runs")
plt.title("Run Comparison (Horizontal)")
plt.yticks(y, years)  # Show actual years instead of 0,1,2,...
plt.legend()
plt.tight_layout()
plt.show()

# %%
a1=np.array([10,20,30,40,50,60])
a1-10

# %%
import numpy as np
players = ["Sachin", "Sehwag", "Kohli", "Yuvraj"] 
runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100,300+600+800+1100+900] 
runs_55yrs = [800+1400+700+1300+1800, 0+1200+900+1400+1600, 0+0+5000+800+1100,300+600+800+1100+900]
x=np.arange(len(players))
width=0.25
plt.barh(x, runs_5yrs, width, color="skyblue", label='5Years') 
plt.barh(x+width, runs_55yrs, width, color="red", label='55Years') 
plt.xlabel("Total Runs in First 5 Years") 
plt.ylabel("Name of Player")
plt.title("First 5-Year Performance of Indian Batsmen") 
plt.yticks(x,players)
plt.legend()
plt.tight_layout() 
plt.show()

# %% [raw]
# Scatter plot started here:

# %%
x=[10,50,5,40,18]
y=[5,6,7,8,12]
plt.scatter(x,y)
plt.show()

# %%
# Histogram

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ages = [ 
34,1,2,3,4,5, 28, 36, 45, 27, 27, 45, 37, 25, 35, 
25, 25, 32, 10, 12, 24, 19, 33, 20, 15, 
44, 27, 30, 15, 24, 31, 18, 33, 23, 27, 
23, 48, 29, 19, 38, 17, 32, 10, 16, 31, 
37, 31, 28, 26, 15, 22, 25, 40, 33, 12, 
33, 26, 23, 36, 40, 39, 21, 26, 33, 39, 
25, 28, 18, 18, 38, 43, 29, 40, 33, 23, 
33, 45, 29, 45, 3, 38, 30, 27, 30, 10, 
27, 33, 44, 24, 21, 24, 39, 33, 24, 35, 
30, 39, 22, 26, 26, 15, 32, 32, 30, 27 
]
bins = [0,10, 20, 30, 40, 50, 60, 70] 
plt.hist(ages,bins=bins, edgecolor='black') 
plt.title('Age Distribution of YouTube Viewers') 
plt.xlabel('Age Group')

# %%
# Pie Plot

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
plt.pie(x)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=["C","C++","Java","Python","Django"]
plt.pie(x,labels=y)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=["C","C++","Java","Python","Django"]
ex=[0.2,0.0,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex, shadow=True,autopct='%0.1f%%',radius=2)
plt.show()

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=["C","C++","Java","Python","Django"]
ex=[0.2,0.0,0.0,0.0,0.0]
color=['r','g','b','y','pink']
plt.pie(x,labels=y,explode=ex, shadow=True,colors=color,autopct='%0.1f%%',radius=0.5)
plt.legend(loc=1)
plt.show()

# %%
# pie chart present in the another pie chart

# %%
x=[10,20,30,40,50]
y=[14,18,19,41,55]
name=["Ankit","Rohit","Mukesh","Shivam","Jai"]

plt.pie(x,labels=name)
plt.show()
